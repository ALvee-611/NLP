# %% [markdown]
# # Exploratory Analysis
#
# The dataset we are using contains the daily record of the top trending YouTube videos.

# %%
import pandas as pd

import os
import pandas as pd
import configparser
#import mysql.connector
from sqlalchemy import create_engine


config = configparser.ConfigParser()
config.read('..\\config.ini')

host = config['mysql']['host']
database = config['mysql']['database']
user = config['mysql']['user']
password = config['mysql']['password']
port = config['mysql']['port']

def read_query(query):
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    df = pd.read_sql(query, con=engine)
    print('Query Executed!')
    return df

# %% [markdown]
# What features do we have?

# %%
q = """
DESCRIBE video_data
"""

read_query(q)
# Out:
# Query Executed!
#                 Field        Type Null Key Default Extra
# 0               title        text  YES        None
# 1         publishedAt        text  YES        None
# 2           channelId        text  YES        None
# 3        channelTitle        text  YES        None
# 4          categoryId      bigint  YES        None
# 5       trending_date        text  YES        None
# 6                tags        text  YES        None
# 7          view_count      bigint  YES        None
# 8               likes      bigint  YES        None
# 9            dislikes      bigint  YES        None
# 10      comment_count      bigint  YES        None
# 11  comments_disabled  tinyint(1)  YES        None
# 12   ratings_disabled  tinyint(1)  YES        None
# 13        description        text  YES        None

# %% [markdown]
# We have 13 features for each video
